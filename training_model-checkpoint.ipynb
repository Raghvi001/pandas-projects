# %%
import pandas as pd
df=pd.read_csv("students.csv")
df.head()
# Out:
#      name   maths  english  science
# 0  raghvi      78       43       64
# 1    aman      90       45       23
# 2  simran      78       23       54
# 3   karan      90       89       90
# 4    neha      23       56       89

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1    maths   5 non-null      int64
#  2   english  5 non-null      int64
#  3   science  5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 288.0+ bytes

# %%
df.describe()
# Out:
#           maths    english    science
# count   5.00000   5.000000   5.000000
# mean   71.80000  51.200000  64.000000
# std    27.93206  24.252835  27.757882
# min    23.00000  23.000000  23.000000
# 25%    78.00000  43.000000  54.000000
# 50%    78.00000  45.000000  64.000000
# 75%    90.00000  56.000000  89.000000
# max    90.00000  89.000000  90.000000

# %%
import matplotlib.pyplot as plt 
plt.scatter(df[" maths"],df["science"])
plt.xlabel("maths marks")
plt.ylabel("science marks")
plt.show()

# %%
x=df[[" maths","science"]]
y=df["english"]
x.head()
y.head()
# Out:
# 0    43
# 1    45
# 2    23
# 3    89
# 4    56
# Name: english, dtype: int64

# %%
 from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (4, 2) (1, 2)
# (4,) (1,)

# %%
from sklearn.linear_model import LinearRegression 
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print("x_test")
print(x_test)
print("\n actuall english marks")
print(y_test.values)
print("\n predicted english marks")
print(y_test)
# Out:
# x_test
#     maths  science
# 1      90       23
#
#  actuall english marks
# [45]
#
#  predicted english marks
# 1    45
# Name: english, dtype: int64
